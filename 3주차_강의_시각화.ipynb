# %% [markdown]
# <a href="https://colab.research.google.com/github/seongheek/econtheory/blob/main/3%EC%A3%BC%EC%B0%A8_%EA%B0%95%EC%9D%98_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **히스토그램**

# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
#주사위를 던졌을 때 나오는 결과를 히스토그램으로 표현하기
import random
print(random.randint(1,6)) #주사위 던지기
# Out:
# 4

# %%
import random
dice=[]
for i in range(5): #다섯번 던짐
  dice.append(random.randint(1,6)) #기존의 dice 변수에 결과를 추가함
print(dice)
# Out:
# [6, 5, 5, 5, 5]

# %%
#저장된 dice 변수의 값을 히스토그램으로 표현해보자
import matplotlib.pyplot as plt
plt.hist(dice, bins=6) #6구간으로 나눔
plt.show()

# %%
#주사위 100번 굴려보기
dice2=[]
for i in range(100):
  dice2.append(random.randint(1,6))
plt.hist(dice2, bins=6) #6구간으로 나눔
plt.show()

# %%
#주사위 100만번(!!!) 굴려보기 - 대수의 법칙이 확인됨
dice3=[]
for i in range(1000000):
  dice3.append(random.randint(1,6))
plt.hist(dice3, bins=6) #6구간으로 나눔
plt.show()

# %% [markdown]
# > ## **연습문제1**
#
#
# 원하는 색깔로 위의 히스토그램을 다시 그린 후 패들렛에 게시해주세요.
# 패들렛 주소: https://padlet.com/nathalieskim/3-4a1bsqjju2au9q9x

# %% [markdown]
# ---
#
#
# ## **막대그래프**

# %%
import matplotlib.pyplot as plt
plt.bar([0,1,2,4,6,10],[1,2,3,5,6,7]) # bar(막대표시x축위치, 막대높이)
plt.show()

# %%
plt.bar([0,3,2,1,6,10],[1,2,3,5,6,7]) #x축이 순서대로 표기되지 않은 경우
plt.show()

# %%
plt.bar(range(6),[1,2,3,5,6,7]) #range() 함수 사용
plt.show()

# %%
#수평막대그래프: barh()
plt.barh(range(6),[1,2,3,5,6,7]) #range() 함수 사용
plt.show()

# %%
plt.barh(range(101),range(101))
# Out:
# <BarContainer object of 101 artists>

# %% [markdown]
# # **파이차트**

# %%
#코랩에 나눔 글꼴 설치

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
#런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
import matplotlib.pyplot as plt
plt.pie([10,20])
plt.show()

# %%
import matplotlib.pyplot as plt
size=[2441,2312,1031,1233]
label=['A형', 'B형', 'O형', 'AB형']

plt.rc('font', family='NanumBarunGothic')
plt.pie(size, labels=label)
plt.show()

# %%
plt.rc('font', family='NanumBarunGothic')
plt.pie(size, labels=label, autopct='%.1f%%')
plt.legend()
plt.show()

# %%
#색 바꾸기, 강조하고 싶은 유형 빼기
plt.rc('font', family='NanumBarunGothic')
color=['darkmagenta', 'deeppink','hotpink', 'pink']
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))
plt.legend()
plt.show()

# %%
#범례위치 바꾸기
plt.rc('font', family='NanumBarunGothic')
color=['darkmagenta', 'deeppink','hotpink', 'pink']
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))
plt.legend(loc='upper right', bbox_to_anchor=(1.2,0.8))
plt.show()

# %% [markdown]
# > ## **연습문제2**
#
#
# 1) 원하는 색깔로 위의 파이차트를 다시 그리고, 2) A형을 튀어나오게 하고, 3) 범례를 파이 중앙으로으로 옮긴 후 패들렛에 게시해주세요.
# 패들렛 주소: https://padlet.com/nathalieskim/3-4a1bsqjju2au9q9x
